# %%
import utils
import datasets
import train
from PIL import Image
from matplotlib import pyplot as plt
# Out:
# Loaded checkpoint from epoch 2222.

# %%
utils.create_data_lists('./BCCD_Dataset/BCCD/', './')
# Out:
# There are 292 training images containing a total of 876 objects. Files have been saved to /home/stan/Netology/Torch/CV.
#
# There are 72 test images containing a total of 216 objects. Files have been saved to /home/stan/Netology/Torch/CV.

# %%
train.main()
# Out:
# /home/stan/deeplearn/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/stan/deeplearn/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loaded base model.
# /home/stan/deeplearn/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch: [0][0/37]	Batch Time 6.128 (6.128)	Data Time 0.431 (0.431)	Loss 16.3709 (16.3709)
# ...

# %%
import eval
import detect
eval.evaluate(eval.test_loader, eval.model)
# Out:
# Evaluating:   0%|                                                                                        | 0/2 [00:00<?, ?it/s]/home/stan/Netology/Torch/CV/model.py:501: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /home/stan/Netology/Torch/CV/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_scores.append(class_scores[1 - suppress])
# Evaluating: 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [00:07<00:00,  3.90s/it]
# {'platelets': 0.8505736589431763,
#  'rbc': 0.8125234246253967,
#  'wbc': 0.9717445373535156}
#
# Mean Average Precision (mAP): 0.878

# %%
img = Image.open('BCCD_Dataset/BCCD/JPEGImages/BloodImage_00000.jpg',mode='r')
img = img.convert('RGB')

# %%
detection_result = detect.detect(img, min_score=0.2, max_overlap=0.5, top_k=200)
plt.imshow(detection_result)
